# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronFriedkin/Skyline-math-200/blob/main/Python_Notebook_Setup_by_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Research Question # 2 : Include question here: Is there an association between smoking an entire cigarette and ever being arrested

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %%
pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %% [markdown]
# Codebook 1

# %% [markdown]
# ![Screen Shot 2023-05-02 at 10.04.41 AM.png](data:image/png;base64,...)

# %%
df['Smoked_Cigs'] = df['H4TO11']

# %%
rp.summary_cat(df['Smoked_Cigs'])
# Out:
#       Variable Outcome  Count  Percent
# 0  Smoked_Cigs       7   4223    64.93
# 1                        1390    21.37
# 2                    1    464     7.13
# 3                    2    310     4.77
# 4                    3     90     1.38
# 5                    4     14     0.22
# 6                    6      8     0.12
# 7                    8      5     0.08

# %%
#Manage data for variable 1

df['Smoked_Cigs'] = df['Smoked_Cigs'].loc[ df['Smoked_Cigs'] !='2' ]
df['Smoked_Cigs'] = df['Smoked_Cigs'].loc[ df['Smoked_Cigs'] !='3' ]
df['Smoked_Cigs'] = df['Smoked_Cigs'].loc[ df['Smoked_Cigs'] !='4' ]
df['Smoked_Cigs'] = df['Smoked_Cigs'].loc[ df['Smoked_Cigs'] !='1' ]
df['Smoked_Cigs'] = df['Smoked_Cigs'].loc[ df['Smoked_Cigs'] !='6' ]
df['Smoked_Cigs'] = df['Smoked_Cigs'].loc[ df['Smoked_Cigs'] !='8' ]
df['Smoked_Cigs'].value_counts()
# Out:
# NO     4223
# YES    1390
# Name: Smoked_Cigs, dtype: int64

# %%
df['Smoked_Cigs'].replace( ['7',' '] , ['NO','YES'], inplace=True)
df['Smoked_Cigs'].value_counts()
# Out:
# NO     4223
# YES    1390
# Name: Smoked_Cigs, dtype: int64

# %%
#Graphs and tables or statistics
df['Smoked_Cigs'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Smoked_Cigs'>

# %% [markdown]
# Codebook 2:

# %% [markdown]
# ![Screen Shot 2023-05-02 at 10.17.15 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['Been_Arrested'] = df['H4CJ1']

# %%
rp.summary_cat(df['Been_Arrested'])
# Out:
#         Variable Outcome  Count  Percent
# 0  Been_Arrested       0   3610    71.77
# 1                          1390    27.63
# 2                      7     30     0.60

# %%
df['Been_Arrested'] = df['Been_Arrested'].loc[ df['Been_Arrested'] !='2' ]
df['Been_Arrested'] = df['Been_Arrested'].loc[ df['Been_Arrested'] !='3' ]
df['Been_Arrested'] = df['Been_Arrested'].loc[ df['Been_Arrested'] !='4' ]
df['Been_Arrested'] = df['Been_Arrested'].loc[ df['Been_Arrested'] !='9' ]
df['Been_Arrested'] = df['Been_Arrested'].loc[ df['Been_Arrested'] !='6' ]
df['Been_Arrested'] = df['Been_Arrested'].loc[ df['Been_Arrested'] !='7' ]
df['Been_Arrested'].value_counts()
# Out:
# 0    3610
#      1390
# Name: Been_Arrested, dtype: int64

# %%
df['Been_Arrested'].replace( ['0',' '] , ['NO','YES'], inplace=True)
df['Been_Arrested'].value_counts()
# Out:
# NO     3610
# YES    1390
# Name: Been_Arrested, dtype: int64

# %%
#Graphs and tables or statistics
df['Been_Arrested'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Been_Arrested'>

# %%
pd.crosstab( df['Been_Arrested'], df['Smoked_Cigs'], normalize='index').plot(kind = 'bar' , stacked = True)
# Out:
# <Axes: xlabel='Been_Arrested'>
